# %% [markdown]
# #Starting Seanorn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import scipy as scm

# %% [markdown]
# Sets the visual style of the plots to resemble the style of the popular data-driven news website "FiveThirtyEight".
# Or simply set some style to the plot

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
#  Loads a built-in dataset called "tips"

# %%
data=sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# There is two functions of seaborn
#
#
# 1.relplot- is a function in seaborn library used to create a relational plot that allows you to visualize the relationship between two variables.
# Syntax for relplot: sns.relplot(x="variable1", y="variable2", data=data)
#
# 2.Scatterplot-is a function in seaborn library used to create a scatter plot, which displays the relationship between two continuous variables as individual data points.
# Syntax for scatterplot: sns.scatterplot(x="variable1", y="variable2", data=data)

# %% [markdown]
#  Scatter plot between total_bill and tip

# %%
sns.relplot(x='total_bill',y='tip',data=data)#here by default the value is scatter plot in kind='scatter'i.e.sns.relplot(x='total_bill',y='tip',data=data)

# %% [markdown]
# The hue parameter:The hue parameter is a useful parameter available in seaborn library, It allows us to specify a categorical variable to differentiate the data points or elements in the plot based on their unique values and can help us to identify useful information from the given dataset.
#
#
# Syntax for relplot with hue parameter: sns.relplot(x="variable1", y="variable2", hue="categorical_variable", data=data)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=data)

# %% [markdown]
# Here in the above figure, we can see that the orange circle denotes the non-smoker data points where as blue points is smoker data and form the above figure we can conclude that the non-smoker tend to give the higher tips than the smoker , where the hue function has make us easier to determine the above information easily.

# %% [markdown]
#  The style parameter:it is also used for categorical data

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',style='sex',data=data)

# %% [markdown]
# The size parameter:It is used for numerical data

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',style='sex',size='size',sizes=(15,200),data=data)

# %% [markdown]
# Using scatterplot:similar as relplot

# %%
sns.scatterplot(x='total_bill',y='tip',hue='smoker',style='sex',data=data)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Plotting with categorical data(catplot)

# %% [markdown]
# 1.Categorical Scatterplots:Here at least one data must be categorical
#
# Types:
#  1.Striplot
#  2.Swarmplot

# %%
# x-axis= categorical data
# y-axis= numerical data
#working in the above data

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='day',y='tip',kind='strip',data=data)

# %% [markdown]
# Jitter:jitter adds random noise to data points along the categorical axis for better visualization.
#
#     In the context of data visualization, "noise" refers to random variation or uncertainty in the data.
#     it means introducing random displacements to the position of the points along the categorical axis.
#     This helps to prevent overlapping of points with the same value, allowing us to see the distribution more clearly.

# %%
sns.catplot(x='day',y='tip',kind='strip',jitter=10,data=data)

# %% [markdown]
# Above as jitter determines the nosie of the above data and if we set the jitter of the above data for visualization to 10 the the distribution of the above data is more scattered

# %%
sns.catplot(x='day',y='tip',kind='swarm',data=data)
# Out:
# C:\Users\Acer\anaconda3\envs\first_proj\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Acer\anaconda3\envs\first_proj\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='tip',hue='sex',data=data)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# A boxplot, as mentioned before, is a visualization that provides a summary of the distribution of a continuous variable. It displays key statistical measures such as the median, quartiles, and potential outliers.
# On the other hand, a PDF (Probability Density Function) is a mathematical function that describes the likelihood of a random variable taking on a specific value or falling within a certain range. It represents the probability distribution of a continuous variable.

# %%
#Univariate-boxplot i.e. with only one parameter from the data set

# %%
sns.boxplot(data['total_bill'])
# Out:
# <Axes: >

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=data)

# %%
sns.catplot(x='day',y='total_bill',hue='sex',kind='box',data=data)

# %% [markdown]
# Violin Plote:violin plots are a method of plotting numeric data and can be sonsidered a comnination of the box plot with a kernel density plot or probability density function.

# %% [markdown]
# -It shows the entire distribution of data
# -Violin plots areoften used ot compare the
# ![image.png](attachment:image.png)

# %%
sns.violinplot(data['total_bill'])
# Out:
# <Axes: >

# %%
sns.catplot(x='day',y='total_bill',kind='violin',data=data)

# %%
sns.catplot(x='day',y='total_bill',kind='violin',hue='sex',data=data)

# %%
#by default split is false split=True,
#in above figure it is clustered in one place so inorder to use the space efficiently we can use split function 
sns.catplot(x='day',y='total_bill',kind='violin',hue='sex',split=True,data=data)

# %% [markdown]
# Barplot and Countplot
#   -Rather than giving the inforamtion about the distribution of data, it gives the information about the central tendency of data.

# %%
#Suppose we want to find the mean value of the tip then we can do it with one categorical data and anothernumerical data
sns.catplot(x='smoker',y='total_bill',kind='bar',hue='sex',data=data)

# %% [markdown]
# The blacked colored bar are the error bar and the are showing the confidence interval to calculate mean for the population.
# confidence interval-A confidence interval is a range of values that provides an estimate of the unknown population parameter. It quantifies the uncertainty associated with an estimate by specifying a range within which the true value of the parameter is likely to fall with a certain level of confidence.

# %%
#here we can add estemator for various other value
#np.median,np.mean,..
import numpy as np
sns.catplot(x='smoker',y='total_bill',kind='bar',hue='sex',estimator=np.std,data=data)

# %%
#Countplot-like histogram for numeriacal data, it works the same for categorical data
sns.catplot(x='sex',kind='count',hue='smoker',data=data)

# %% [markdown]
# Heatmaps-A heat map is a graphical representation of data where the individual values conatined in a matrix are represendted as colors.
#
# it is used with discrete numerical data and two categorical data

# %%
flight=sns.load_dataset('flights')

# %%
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# #creating the pivot table for above data
#
# A pivot table is used in data analysis to summarize and analyze large datasets by organizing and aggregating the data based on specific variables or dimensions. It allows you to extract insights and patterns from complex data by providing a clear and structured view of the information.
#
# Here's an example to illustrate the use of a pivot table in data analysis:
#
# Let's say you have a dataset containing sales data for a company. The dataset includes columns such as "Region" (representing different geographic regions), "Product" (representing different product categories), and "Sales" (representing the sales figures for each combination of region and product).
#
# By creating a pivot table, you can easily analyze the total sales for each region and product category. The pivot table would have the "Region" variable as rows, the "Product" variable as columns, and the "Sales" variable as the aggregated values within the table cells. This would allow you to quickly identify which regions and product categories are performing well in terms of sales and identify any trends or patterns.
#
# In summary, a pivot table simplifies data analysis by summarizing and organizing data in a flexible and customizable format, enabling users to gain insights and make informed decisions based on the summarized information.

# %% [markdown]
# flight.pivot_table(index='year',columns='month',values='passengeres',aggfunc='sum')
#
# The code `flight.pivot_table(index='year', columns='month', values='passengers', aggfunc='sum')` uses the `pivot_table` function on a DataFrame called `flight` to create a summary table that aggregates the data based on the year and month columns.
#
# - `index='year'`: This specifies that the "year" column will be used as the index (rows) of the pivot table.
# - `columns='month'`: This specifies that the "month" column will be used as the columns of the pivot table.
# - `values='passengers'`: This specifies that the "passengers" column will be used as the values to be aggregated within the pivot table cells.
# - `aggfunc='sum'`: This specifies that the aggregation function to be used is the sum, which means the values in each cell will be the sum of the passenger counts for the corresponding year and month combination.
#
# The resulting pivot table will have the years as the index (rows) and the months as the columns. Each cell will contain the sum of the passenger counts for that specific year and month combination.
#
# This pivot table can provide valuable insights into the passenger traffic trends over the years and across different months, allowing for easy identification of patterns or seasonal variations in the data.

# %%
x=flight.pivot_table(index='year',columns='month',values='passengers',aggfunc='sum')
x
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(x)
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %% [markdown]
# We can conclude from above diagram is that later the year the more passenger there is and the month of jul and aug has the highest passenger from the above color bar

# %%
sns.heatmap(x,cbar=False,linewidth=0.5)
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
#d=it represent that the format is the integer
#Cmap for color eg.Cmap=winter,summer..
#anno-helps us to give the individual data
sns.heatmap(x,cbar=False,linewidth=0.5,annot=True,fmt='d',cmap='summer')
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %% [markdown]
# A dendrogram is a diagram representing a tree.
#
# Clustermap:for more info click https://seaborn.pydata.org/generated/seaborn.clustermap.html

# %%
#row_cluster or column_cluster = It is used to group the similar value in the same cluster or in one column i.e.any value is not repeated
sns.clustermap(x,z_score=0,annot=True,col_cluster=False,metric='correlation')

# %% [markdown]
# Jointplot:
# A joint plot is a visualization in seaborn that combines multiple plots to show the relationship between two variables. It provides a scatter plot by default and can also include other plots such as histograms and regression lines.
#
#
# Syntax for creating a joint plot using seaborn:
# sns.jointplot(x='variable1', y='variable2', data=data, kind='scatter')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#by default it display scatter plot so we donot set kind='scattter'
sns.jointplot(x='total_bill',y='tip',data=data)

# %%
#hexplot = It is a 2-D histogram
sns.jointplot(x='total_bill',y='tip',kind='hex',data=data)

# %% [markdown]
# A KDE (Kernel Density Estimation) plot is a type of plot that estimates the probability density function of a continuous variable. It provides a smooth curve that represents the underlying distribution of the data.

# %%
sns.jointplot(x='total_bill',y='tip',kind='kde',data=data)

# %%
#Regression Plot:A regplot is a type of plot in seaborn that displays a scatter plot with a fitted regression line. It provides a visualization of the relationship between two variables and allows you to assess the linear relationship between them.
sns.jointplot(x='total_bill',y='tip',kind='reg',data=data)

# %% [markdown]
# Pairplot:A pair plot is a type of plot in seaborn that allows you to visualize pairwise relationships between multiple variables in a dataset. It creates a grid of scatter plots and histograms, showing the relationships and distributions of variables.
#     sns.pairplot(data, vars=['variable1', 'variable2', ...])

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# Distplot=The distplot function in seaborn is used to visualize the distribution of a single variable. It combines a histogram with a kernel density estimate (KDE) plot, providing insights into the shape, central tendency, and spread of the data.
#
# sns.distplot(data['variable'], kde=True)

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#here we can see that the age column is not fully filled with the data, i.e. there is some missing values
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic['age'].fillna(titanic['age'].mean(),inplace=True)

# %%
#new distplot = histplot or displot 
sns.histplot(titanic['age'],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# Ploting only histogram

# %%
#bins=
sns.displot(titanic['age'],bins=10)

# %%
#Plotting KDE
#new
sns.kdeplot(titanic['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
#rugplot

sns.rugplot(titanic['age'])
# Out:
# <Axes: xlabel='age'>

# %%
#Where and how can i use distplot?
#1=survived
#0=dead
sns.histplot(titanic[titanic['survived']==1]['age'],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# The code `sns.displot(titanic[titanic['survived']==1]['age'])` creates a distribution plot (displot) using seaborn to visualize the distribution of ages for passengers who survived in the Titanic dataset.
#
# In this code:
# - `titanic[titanic['survived']==1]` filters the Titanic dataset to include only the rows where the 'survived' column has a value of 1, indicating the passengers who survived.
# - `['age']` selects the 'age' column from the filtered dataset, representing the ages of the surviving passengers.
# - `sns.displot()` is used to create the distribution plot. It will display a histogram and/or a kernel density estimate (KDE) plot, depending on the default behavior or specified options.
#
# The resulting distribution plot will show the frequency or density of ages for the passengers who survived, providing insights into the age distribution of survivors in the Titanic dataset.

# %%
#comparision between ages of people who have died and who have survived
sns.histplot(titanic[titanic['survived']==1]['age'],kde=True)
sns.histplot(titanic[titanic['survived']==0]['age'],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# From above diagram we can conclude various information such as the age of people who died and survied more ....
